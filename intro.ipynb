# %%
from langchain_community.document_loaders import PyPDFLoader

loader=PyPDFLoader(r'docs\Recent_Wars_Extended_Research_Report.pdf')

# %%
texts=loader.load()
# Out:
# incorrect startxref pointer(1)
# parsing for Object Streams

# %%
from langchain_core.prompts import ChatMessagePromptTemplate,SystemMessagePromptTemplate,ChatPromptTemplate

# %%
template = """
You are a highly skilled research agent.

I will provide you with a topic related to ongoing wars.
Your task is to research the topic in depth and provide a well-structured, factual, and analytical response.

Guidelines:
- Length: 400-500 words
- Tone: Academic and neutral
- Structure the answer with clear paragraphs
- Cover background, key developments, military aspects, economic impact, and social/crime-related consequences
- Focus on recent and ongoing conflicts
- Avoid opinions; rely on objective analysis

"""

system_prompt=SystemMessagePromptTemplate.from_template(template=template)

# %%
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.prompts import HumanMessagePromptTemplate
from langchain_core.output_parsers import PydanticOutputParser
from pydantic import BaseModel


class OutputResponse(BaseModel):
    title: str
    content: str


parser = PydanticOutputParser(pydantic_object=OutputResponse)


human_prompt = HumanMessagePromptTemplate.from_template(
    """
Write a 400-500 word response about:

Topic: {topic}

Tone: {tone}

Return ONLY valid JSON containing:
"title": a suitable title
"content": the 400-500 word response
"""
)

final_prompt = ChatPromptTemplate.from_messages([
    system_prompt,
    human_prompt
])

# %%
from langchain_core.output_parsers import StrOutputParser,PydanticOutputParser
from langchain_groq.chat_models import ChatGroq
from dotenv import load_dotenv

# %%
import os
api_key=os.getenv('GROQ_API_KEY')
load_dotenv()

model=ChatGroq(api_key=api_key,model="openai/gpt-oss-safeguard-20b"
) #type: ignore

# %%
from pydantic import BaseModel
class OutputResponse(BaseModel):
    title:str
    content:str

# %%
structured_llm  =model.with_structured_output(OutputResponse,    method="json_mode"
)

# %%
chain=final_prompt|structured_llm

# %%
response=chain.invoke({
    "topic":"Russia-Ukraine War",
    "tone":"Informative and academic"

})

# %%
response
# Out:
# OutputResponse(title='Russia‑Ukraine War: Recent Developments and Consequences', content='Background: The conflict began on 24 February 2022 when Russia launched a full‑scale invasion of Ukraine after years of tension over Crimea and the Donbas region. Initial Russian advances into eastern and southern Ukraine were halted by Ukrainian resistance and Western aid, leading to a strategic stalemate by late spring. Since then, the war has become a hybrid contest of conventional battles, cyber operations, and information warfare.\n\nKey Developments: By July 2023, Ukrainian forces regained districts in Kharkiv and Bakhmut, illustrating effective counter‑offensives. In September 2023, Russia shifted to attrition and siege tactics, while Ukraine intensified precision strikes against logistics hubs. Advanced missile systems such as HIMARS and Iskander increased battlefield casualties and infrastructure damage. Attempts at a Minsk‑III ceasefire have failed, leaving the front line largely static.\n\nMilitary Aspects: The war blends conventional and asymmetric tactics. Russian mechanized units and artillery barrages confront Ukrainian rapid‑mobility forces equipped with anti‑tank munitions and drones. Cyber attacks target Ukrainian power grids and communications, complementing physical combat. Equipment losses are significant: Ukraine has lost ~30% of its armored vehicles, while Russia has lost ~15% of its tank fleet. Autonomous unmanned systems and electronic warfare platforms have altered operational tempos, reducing human exposure in high‑risk zones.\n\nEconomic Impact: Sanctions against Russia target banking, energy, and defense, constraining war financing. Russia’s pivot to non‑Western markets partially offsets revenue losses, but its economy contracted ~20% of GDP by 2025. Ukraine’s GDP fell 15% in 2023 due to destroyed industrial hubs. Global supply chains, especially grain and fertilizer, are strained, raising food prices worldwide. Digital payment systems have accelerated as traditional banking routes are curtailed.\n\nSocial and Crime‑Related Consequences: The war has produced a displacement crisis, with over 5 million internally displaced persons and 3.5 million refugees. Human rights groups report widespread civilian casualties and alleged war crimes, including attacks on medical facilities. Psychological tolls are high, with rising PTSD reports. Organized crime networks exploit looted resources, and reconstruction faces widespread destruction, demographic shifts, and lingering security concerns.')

# %%
# Response contains title and content so i have to extract them for each topic in the pdf provided

response
# Out:
# OutputResponse(title='Russia‑Ukraine War: Recent Developments and Consequences', content='Background: The conflict began on 24 February 2022 when Russia launched a full‑scale invasion of Ukraine after years of tension over Crimea and the Donbas region. Initial Russian advances into eastern and southern Ukraine were halted by Ukrainian resistance and Western aid, leading to a strategic stalemate by late spring. Since then, the war has become a hybrid contest of conventional battles, cyber operations, and information warfare.\n\nKey Developments: By July 2023, Ukrainian forces regained districts in Kharkiv and Bakhmut, illustrating effective counter‑offensives. In September 2023, Russia shifted to attrition and siege tactics, while Ukraine intensified precision strikes against logistics hubs. Advanced missile systems such as HIMARS and Iskander increased battlefield casualties and infrastructure damage. Attempts at a Minsk‑III ceasefire have failed, leaving the front line largely static.\n\nMilitary Aspects: The war blends conventional and asymmetric tactics. Russian mechanized units and artillery barrages confront Ukrainian rapid‑mobility forces equipped with anti‑tank munitions and drones. Cyber attacks target Ukrainian power grids and communications, complementing physical combat. Equipment losses are significant: Ukraine has lost ~30% of its armored vehicles, while Russia has lost ~15% of its tank fleet. Autonomous unmanned systems and electronic warfare platforms have altered operational tempos, reducing human exposure in high‑risk zones.\n\nEconomic Impact: Sanctions against Russia target banking, energy, and defense, constraining war financing. Russia’s pivot to non‑Western markets partially offsets revenue losses, but its economy contracted ~20% of GDP by 2025. Ukraine’s GDP fell 15% in 2023 due to destroyed industrial hubs. Global supply chains, especially grain and fertilizer, are strained, raising food prices worldwide. Digital payment systems have accelerated as traditional banking routes are curtailed.\n\nSocial and Crime‑Related Consequences: The war has produced a displacement crisis, with over 5 million internally displaced persons and 3.5 million refugees. Human rights groups report widespread civilian casualties and alleged war crimes, including attacks on medical facilities. Psychological tolls are high, with rising PTSD reports. Organized crime networks exploit looted resources, and reconstruction faces widespread destruction, demographic shifts, and lingering security concerns.')

# %%
titles=[]
for page in texts:
    title=page.page_content.split('\n')[0]
    titles.append(title)

# %%
titles
# Out:
# ['Recent Wars and Ongoing Conflicts: Extended Global',
#  '1. Russia–Ukraine War',
#  '2. Israel–Gaza War',
#  '3. Sudan Civil War',
#  '4. Ethiopia Internal Conflicts',
#  '5. Democratic Republic of Congo',
#  '6. Myanmar Civil War']

# %%
contents=[]
for title in titles:
    response=chain.invoke({
        "topic":title,
        "tone":"Academic and Informative "
    })
    contents.append(response.content)

# %%
final_content = {}

for title, content in zip(titles, contents):
    final_content[title] = content

# %%
final_content=dict(zip(titles, contents))

# %%
final_content
# Out:
# {'Recent Wars and Ongoing Conflicts: Extended Global': "Recent wars and ongoing conflicts across the globe reflect complex geopolitical dynamics, shifting alliances, and evolving military technologies. This analysis focuses on the major contemporary theaters—Ukraine, Yemen, Ethiopia’s Tigray region, and the South China Sea disputes—examining background, key developments, military aspects, economic impact, and social or crime-related consequences.\n\nUkraine (2022‑present)\nBackground: The conflict began with Russia’s full‑scale invasion in February 2022, following years of tension over NATO expansion and Ukraine’s domestic reforms. Key developments include the rapid Ukrainian counter‑offensives in Kharkiv and Kherson, the capture of key airfields, and the integration of Western aid. Military aspects feature hybrid warfare, extensive use of drones, and cyber operations. Economically, sanctions on Russia have disrupted global energy markets, while Ukrainian grain exports face logistical challenges. Socially, millions of internally displaced persons (IDPs) and refugees have strained neighboring countries. Crime‑related outcomes include increased incidents of war crimes, illicit arms trafficking, and cyber‑crime targeting critical infrastructure.\n\nYemen (2014‑present)\nBackground: A civil war erupted when Houthi forces seized Sana’a, prompting a Saudi‑led coalition to intervene. Key developments encompass the 2020 ceasefire attempt and the 2021–2022 humanitarian crises. Military aspects involve asymmetric warfare, the use of ballistic missiles by Houthi rebels, and frequent airstrikes by coalition forces. Economically, the war has devastated Yemen’s oil industry and crippled its fishing sector, contributing to widespread food insecurity. Socially, the conflict has led to a severe famine, a cholera outbreak, and the displacement of over 4 million people. Crime-related issues include the proliferation of small arms and the rise of criminal networks exploiting the porous borders.\n\nEthiopia’s Tigray (2020‑2022)\nBackground: Tension between the Tigray People's Liberation Front (TPLF) and the federal government escalated into armed conflict in November 2020. Key developments involve the 2021 peace agreement, the subsequent humanitarian assistance, and the lingering tensions in the Amhara region. Military aspects feature heavy artillery, air raids, and the involvement of Eritrean forces. Economically, the conflict disrupted Ethiopia’s coffee exports and caused significant infrastructure damage. Socially, the war induced mass displacement, widespread sexual violence, and the breakdown of healthcare services. Crime-related outcomes include allegations of war crimes, looting, and the emergence of armed militias.\n\nSouth China Sea (ongoing)\nBackground: Territorial disputes among China, Vietnam, the Philippines, and Malaysia persist over resource-rich maritime zones. Key developments include China’s construction of artificial islands, the 2022 “Freedom of Navigation” exercises by the United States, and diplomatic negotiations in 2023. Military aspects involve naval patrols, missile tests, and the deployment of advanced surveillance systems. Economically, the region remains critical for global shipping lanes, with over 30% of world trade passing through. Socially, local fishing communities face displacement and resource conflicts. Crime-related concerns revolve around maritime piracy, illegal fishing, and smuggling networks.\n\nCommon Threads and Global Implications\nAcross these conflicts, the convergence of conventional and unconventional warfare tactics is evident. Modern conflicts increasingly rely on cyber capabilities, unmanned systems, and information operations, complicating traditional battlefield assessments. Economically, sanctions, trade disruptions, and resource scarcity ripple through global markets, affecting energy prices, commodity supplies, and supply chains. Socially, large-scale displacement, civilian casualties, and  ...
no direct military aid has been authorized, leaving the conflict largely a domestic contest of resources and manpower.\n\nSudan’s economy, already fragile after the secession of South Sudan, has suffered a steep contraction. Oil production fell from 2.5\u202fmillion barrels per day in 2019 to under 500,000 barrels in 2023 due to damaged pipelines and disrupted refinery operations. The Central Bank’s currency, the Sudanese pound, has depreciated by more than 70% against the US dollar, pushing inflation above 200%. The conflict has halted grain imports, exacerbating food insecurity that affects over 10\u202fmillion people. International aid flows have dwindled, and the United Nations has reported a 35% decline in humanitarian assistance since the outbreak, leaving millions reliant on emergency relief.\n\nThe war has produced a humanitarian catastrophe, with the United Nations estimating over 20,000 civilian deaths and more than 2\u202fmillion internally displaced persons as of early 2024. Reports from human rights organizations detail widespread sexual violence, abductions, and forced recruitment of children by both the SAF and RSF. In addition, the RSF’s control over the north has led to the establishment of “safe zones” that have become sites of mass graves and allegations of war crimes. The conflict has also disrupted educational and health services, with schools closed and hospitals overwhelmed by casualties. The pervasive insecurity has fostered a climate of fear that extends beyond combat zones, contributing to a rise in organized crime, including smuggling and illicit arms trafficking.",
#  '4. Ethiopia Internal Conflicts': 'Ethiopia’s internal conflicts stem from its federal structure, established by the 1995 constitution, which divided the country into 13 regional states with autonomy over local matters while the central government controlled security. Designed to manage ethnic diversity, this arrangement also fostered competition for resources and political influence. The 2018 election of Prime Minister Abiy Ahmed triggered rapid liberalization and anti‑corruption campaigns, intensifying inter‑regional rivalries and setting the stage for renewed violence.\n\nKey recent conflicts include the Tigray War (2020‑2022), the Amhara insurgency, Oromo protests, and the Somali region’s al‑Shabaab‑driven instability, significantly escalating regional tensions. The Tigray conflict began after a disputed 2020 election and perceived threat to national authority, prompting the Ethiopian National Defense Force (ENDF) and allied militias, with Eritrean support, to launch a large‑scale offensive. Amhara forces and Tigray Defense Forces (TDF) have clashed over border villages, while Oromo groups have engaged in sporadic skirmishes with federal troops. In Somali, al‑Shabaab and local warlords contest control, complicating the security landscape.\n\nMilitary dynamics combine conventional forces with irregular militias. The ENDF has employed air power, artillery, and drones, while local militias use improvised weapons and guerrilla tactics. The TDF’s 2021 drone strikes marked a shift in asymmetric warfare. Humanitarian corridors and ceasefire agreements, notably the 2022 UN‑AU mediated deal, have been fragile, with frequent violations. The presence of Eritrean troops in Tigray and Ethiopian deployments along the Sudan border underscore the regional dimension of these internal disputes.\n\nEconomically, Ethiopia’s GDP contracted 1.9% in 2022, reversing years of growth. Over 3 million people displaced, disrupting agriculture and urban labor. Damage to railways, irrigation, and infrastructure reduced export capacity. Aid inflows exceeded $1.2\u202fbillion in 2021, yet reconstruction and security spending strained public finances. Commodity prices, especially coffee, fluctuated due to supply disruptions, affecting export revenues. Additionally, the conflict has increased import costs and reduced foreign investment, further hampering growth prospects, particularly in the industrial and service sectors.\n\nSocially, mass displacement has strained host communities, while reports of human rights abuses—including extrajudicial killings, sexual violence, and forced labor—have surfaced. Lawlessness in conflict zones has spurred looting, armed robbery, and small‑arms proliferation. The diaspora has suffered economic losses and intensified lobbying for international mediation. These developments underscore the fragile nexus between Ethiopia’s internal conflicts, its socioeconomic fabric, and regional stability. The cumulative impact threatens to erode social cohesion and could prolong the cycle of conflict if not addressed through inclusive political solutions.',
#  '6. Myanmar Civil War': 'Myanmar’s contemporary civil war is rooted in a colonial legacy and a history of contested governance. After independence in 1948, successive civilian administrations were punctuated by military coups, most notably the 1988 “8888 Uprising” and the 1990 elections that the National League for Democracy won but were suppressed. A 2011 transition to a quasi‑civilian regime and the 2015 election of Aung San Suu Kyi’s NLD were perceived as democratization steps, yet the military retained 25\u202f% of parliamentary seats and control over key ministries. The 2021 coup, which removed the elected government, reignited resistance and introduced a new phase of armed conflict involving the Tatmadaw and a coalition of ethnic armed organisations (EAOs).\n\nKey developments since 2015 include the Nationwide Ceasefire Agreement (NCA) that temporarily united 15 major EAOs, but the 2021 coup dissolved the peace process and triggered renewed hostilities in Shan, Kachin, and Karen states. The National Unity Government (NUG) and “People’s Defence Forces” (PDFs) emerged in 2021, creating a domestic opposition that operates alongside established ethnic militias. By 2023, the Tatmadaw intensified offensives against the Arakan Army in Rakhine and engaged with the Kachin Independence Army and Shan State Army – North, while external actors such as China and India provide logistical support, complicating the conflict landscape.\n\nMilitarily, the Tatmadaw fields a conventional army with mechanised and air assets, supported by the State Law and Order Restoration Council. Ethnic armed groups vary from well‑equipped units of the AA and KIA to smaller guerrilla factions. Operations increasingly involve improvised explosive devices, ambushes, and artillery, resulting in a protracted low‑intensity war. Counter‑insurgency strategies combine kinetic operations with selective political concessions, yet the fragmented command among EAOs limits coordinated resistance. The rise of PDFs blurs civilian‑military distinctions, raising concerns over the application of international humanitarian law.\n\nEconomic impacts are significant. Foreign direct investment has fallen, especially in jade and timber, which are mined in conflict zones. Sanctions from the United States and the European Union target military procurement and wealthy individuals, constraining the Tatmadaw’s budget. Infrastructure damage, particularly to transport and energy networks, has disrupted supply chains, lowering GDP growth from 5.7\u202f% in 2019 to about 2.1\u202f% in 2023. Over five million people displaced have strained urban economies and diverted public funds toward humanitarian assistance.\n\nSocially, the war has produced a humanitarian crisis. UN reports cite more than 3.5\u202fmillion internally displaced persons and 1.4\u202fmillion refugees, predominantly to neighboring countries. Human rights violations—including extrajudicial killings, sexual violence, and forced labour—are documented by NGOs. Ethnic cleansing campaigns in Rakhine State have led to allegations of war crimes against Rohingya civilians. The insecurity also fuels illicit trade, such as opium production and weapons trafficking, further destabilizing the region.'}

# %%
def clean_text(text: str) -> str:
    return (
        text
        .replace("\u00a0", " ")   # non-breaking space
        .replace("\u202f", " ")   # narrow no-break space
        .replace("–", "-")        # en dash
        .replace("—", "-")        # em dash
    )

# %%
from reportlab.platypus import (
    SimpleDocTemplate,
    Paragraph,
    Spacer,
    PageBreak
)
from reportlab.lib.styles import getSampleStyleSheet, ParagraphStyle
from reportlab.lib.pagesizes import A4


import re

import re

def clean_text_hard(text: str) -> str:
    if not text:
        return ""

    replacements = {
        "\u25A0": " ",   # black square ■
        "\u00a0": " ",
        "\u202f": " ",
        "\u2009": " ",
        "\u2007": " ",
        "\u200b": "",
        "\u2060": "",
        "–": "-",
        "—": "-",
        "‐": "-",
    }

    for bad, good in replacements.items():
        text = text.replace(bad, good)

    # Fix broken words like counter offensives
    text = re.sub(r"\s+", " ", text)

    return text.strip()




def regenerate_pdf_from_dict(content_dict, output_path):
    doc = SimpleDocTemplate(
        output_path,
        pagesize=A4,
        rightMargin=50,
        leftMargin=50,
        topMargin=50,
        bottomMargin=50
    )

    styles = getSampleStyleSheet()

    styles.add(ParagraphStyle(
        name="SectionTitle",
        fontSize=15,
        leading=18,
        spaceAfter=12
    ))

    styles.add(ParagraphStyle(
        name="SectionBody",
        fontSize=11,
        leading=15,
        spaceAfter=10
    ))

    story = []

    for i, (heading, text) in enumerate(content_dict.items()):
        cleaned_heading = clean_text(heading)
        cleaned_text = clean_text(text)

        story.append(
            Paragraph(f"<b>{cleaned_heading}</b>", styles["SectionTitle"])
        )
        story.append(Spacer(1, 10))

        story.append(
            Paragraph(
                cleaned_text.replace("\n", "<br/>"),
                styles["SectionBody"]
            )
        )

        if i != len(content_dict) - 1:
            story.append(PageBreak())

    doc.build(story)

# %%
regenerate_pdf_from_dict(
    content_dict=final_content,
    output_path="docs/Recent_Wars_Final_Report_modified.pdf"
)

# %%
from langchain_community.document_loaders import PyPDFLoader
loader=PyPDFLoader(r'docs\Recent_Wars_Final_Report_modified.pdf')
docs=loader.load()

# %%
docs
# Out:
# [Document(metadata={'producer': 'ReportLab PDF Library - (opensource)', 'creator': '(unspecified)', 'creationdate': '2026-08-28T14:14:12+05:00', 'author': '(anonymous)', 'keywords': '', 'moddate': '2026-08-28T14:14:12+05:00', 'subject': '(unspecified)', 'title': '(anonymous)', 'trapped': '/False', 'source': 'docs\\Recent_Wars_Final_Report_modified.pdf', 'total_pages': 10, 'page': 0, 'page_label': '1'}, page_content="Recent Wars and Ongoing Conflicts: Extended Global\nRecent wars and ongoing conflicts across the globe reflect complex geopolitical dynamics, shifting\nalliances, and evolving military technologies. This analysis focuses on the major contemporary\ntheaters-Ukraine, Yemen, Ethiopia’s Tigray region, and the South China Sea disputes-examining\nbackground, key developments, military aspects, economic impact, and social or crime-related\nconsequences.\nUkraine (2022■present)\nBackground: The conflict began with Russia’s full■scale invasion in February 2022, following years\nof tension over NATO expansion and Ukraine’s domestic reforms. Key developments include the\nrapid Ukrainian counter■offensives in Kharkiv and Kherson, the capture of key airfields, and the\nintegration of Western aid. Military aspects feature hybrid warfare, extensive use of drones, and\ncyber operations. Economically, sanctions on Russia have disrupted global energy markets, while\nUkrainian grain exports face logistical challenges. Socially, millions of internally displaced persons\n(IDPs) and refugees have strained neighboring countries. Crime■related outcomes include\nincreased incidents of war crimes, illicit arms trafficking, and cyber■crime targeting critical\ninfrastructure.\nYemen (2014■present)\nBackground: A civil war erupted when Houthi forces seized Sana’a, prompting a Saudi■led\ncoalition to intervene. Key developments encompass the 2020 ceasefire attempt and the\n2021-2022 humanitarian crises. Military aspects involve asymmetric warfare, the use of ballistic\nmissiles by Houthi rebels, and frequent airstrikes by coalition forces. Economically, the war has\ndevastated Yemen’s oil industry and crippled its fishing sector, contributing to widespread food\ninsecurity. Socially, the conflict has led to a severe famine, a cholera outbreak, and the\ndisplacement of over 4 million people. Crime-related issues include the proliferation of small arms\nand the rise of criminal networks exploiting the porous borders.\nEthiopia’s Tigray (2020■2022)\nBackground: Tension between the Tigray People's Liberation Front (TPLF) and the federal\ngovernment escalated into armed conflict in November 2020. Key developments involve the 2021\npeace agreement, the subsequent humanitarian assistance, and the lingering tensions in the\nAmhara region. Military aspects feature heavy artillery, air raids, and the involvement of Eritrean\nforces. Economically, the conflict disrupted Ethiopia’s coffee exports and caused significant\ninfrastructure damage. Socially, the war induced mass displacement, widespread sexual violence,\nand the breakdown of healthcare services. Crime-related outcomes include allegations of war\ncrimes, looting, and the emergence of armed militias.\nSouth China Sea (ongoing)\nBackground: Territorial disput
 2023, the Tatmadaw intensified offensives against the Arakan Army\nin Rakhine and engaged with the Kachin Independence Army and Shan State Army - North, while\nexternal actors such as China and India provide logistical support, complicating the conflict\nlandscape.\nMilitarily, the Tatmadaw fields a conventional army with mechanised and air assets, supported by\nthe State Law and Order Restoration Council. Ethnic armed groups vary from well■equipped units\nof the AA and KIA to smaller guerrilla factions. Operations increasingly involve improvised explosive\ndevices, ambushes, and artillery, resulting in a protracted low■intensity war. Counter■insurgency\nstrategies combine kinetic operations with selective political concessions, yet the fragmented\ncommand among EAOs limits coordinated resistance. The rise of PDFs blurs civilian■military\ndistinctions, raising concerns over the application of international humanitarian law.\nEconomic impacts are significant. Foreign direct investment has fallen, especially in jade and\ntimber, which are mined in conflict zones. Sanctions from the United States and the European\nUnion target military procurement and wealthy individuals, constraining the Tatmadaw’s budget.\nInfrastructure damage, particularly to transport and energy networks, has disrupted supply chains,\nlowering GDP growth from 5.7 % in 2019 to about 2.1 % in 2023. Over five million people displaced\nhave strained urban economies and diverted public funds toward humanitarian assistance.\nSocially, the war has produced a humanitarian crisis. UN reports cite more than 3.5 million internally\ndisplaced persons and 1.4 million refugees, predominantly to neighboring countries. Human rights\nviolations-including extrajudicial killings, sexual violence, and forced labour-are documented by\nNGOs. Ethnic cleansing campaigns in Rakhine State have led to allegations of war crimes against\nRohingya civilians. The insecurity also fuels illicit trade, such as opium production and weapons\ntrafficking, further destabilizing the region.')]

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter

text_splitter=RecursiveCharacterTextSplitter(chunk_size=500,chunk_overlap=200)

final_chunk_docs=text_splitter.split_documents(documents=docs)

# %%
len(final_chunk_docs)
# Out:
# 92

# %%
final_docs=[]
for doc in final_chunk_docs:
    cleaned_text = clean_text_hard(doc.page_content)
    if cleaned_text.strip():   # empty check
        final_docs.append(cleaned_text)

# %%
# %pip install bm25s
# Out:
# Note: you may need to restart the kernel to use updated packages.
# c:\Users\user\Desktop\RAG\.venv\Scripts\python.exe: No module named pip

# %%
import bm25s

final_docs = [
    clean_text_hard(doc.page_content)
    for doc in final_chunk_docs
    if doc.page_content.strip()
]

corpus_tokens = bm25s.tokenize(
    final_docs,
    stopwords="en"
)
text_retriever = bm25s.BM25()
text_retriever.index(corpus_tokens)

# %%
from sentence_transformers import SentenceTransformer
from typing import List

model = SentenceTransformer("all-MiniLM-L6-v2")

def generate_embeddings(model,final_docs:List[str]):
    embeddings = model.encode(final_docs)
    return embeddings
# Out:
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Loading weights: 100%|██████████| 103/103 [00:00<00:00, 403.78it/s, Materializing param=pooler.dense.weight]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.

# %%
from pinecone import Pinecone

load_dotenv()


pinecone_api_key=os.getenv('PINECONE_API_KEY')
pc=Pinecone(
    api_key=pinecone_api_key
)

# %%
index = pc.Index(
    name="vectordb",
    pool_threads=50,             # <-- make sure to set these
    connection_pool_maxsize=50,  # <-- make sure to set these
)

# %%
# vectors = []

# for i, (text, embedding) in enumerate(zip(final_docs, embeddings)):
#     if not text.strip():
#         continue

#     vectors.append(
#         (
#             f"doc-{i}",
#             embedding.tolist(),
#             {
#                 "text": text,
#                 "source": "pdf",
#                 "chunk_id": i
#             }
#         )
#     )

# %%
def batch_upsert(index, vectors, batch_size=100):
    for i in range(0, len(vectors), batch_size):
        index.upsert(vectors=vectors[i:i+batch_size])

# %%
# batch_upsert(index, vectors)

# %%
# index.describe_index_stats()

# %%
# query = "impact of wars on global economy"
# q_vec = model.encode([query])[0]

# res = index.query(
#     vector=q_vec.tolist(),
#     top_k=5,
#     include_metadata=True
# )

# for m in res["matches"]:
#     print(m["score"], m["metadata"]["text"][:100])

# %%
def join_context(matches):
    texts = []

    for match in matches:
        metadata = match.get("metadata", {})
        text = metadata.get("text")
        if text:
            texts.append(text)

    return "\n\n".join(texts)

# %%
import os
api_key=os.getenv('GROQ_API_KEY')
load_dotenv()

llm=ChatGroq(api_key=api_key,model="openai/gpt-oss-120b") #type: ignore

# %%
template="""

You are a smart and honest student.

You must answer questions using ONLY the information provided in the context.
You are NOT allowed to use any external knowledge, assumptions, or guesses.

If the answer is NOT explicitly present in the context,
you must reply exactly with:
"I don't know the answer."

Do not add anything else.

"""
system_prompt=SystemMessagePromptTemplate.from_template(template=template)

# %%
template="""

Context:
{context}

Question:
{question}

"""

human_prompt=HumanMessagePromptTemplate.from_template(template=template)

# %%
final_prompt=ChatPromptTemplate(
    messages=[
        system_prompt,human_prompt
    ]
)

# %%
chain=final_prompt|llm|StrOutputParser()

# %% [markdown]
# ### Generating Pipeline

# %%
from langchain_community.document_loaders import PyPDFLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter


def document_loader(path:str):
    loader=PyPDFLoader(path)
    docs=loader.load()
    return docs

# %%
from typing import List
from langchain_core.documents import Document
def splitting_the_text(docs:List[Document]):
    text_splitter=RecursiveCharacterTextSplitter(chunk_size=500,chunk_overlap=200)
    final_chunk_docs=text_splitter.split_documents(documents=docs)
    return final_chunk_docs

# %%
def formatting(final_chunk_docs:List[Document]):
    final_docs=[]
    for doc in final_chunk_docs:
        cleaned_text = clean_text_hard(doc.page_content)
        if cleaned_text.strip():   # empty check
            final_docs.append(cleaned_text)
    return final_docs

# %%
# import bm25s
# bm25_retriever = bm25s.BM25()
def generate_embeddings(model,final_docs:List[str],bm25_retriever):
    tokens = bm25s.tokenize(
        final_docs,
        stopwords="en"
    )
    bm25_retriever.index(tokens)
    embeddings = model.encode(final_docs)
    return embeddings,bm25_retriever


def insertion_in_pinecone(final_docs:List[str],embeddings):
    vectors = []

    for i, (text, embedding) in enumerate(zip(final_docs, embeddings)):
        if not text.strip():
            continue

        vectors.append(
            (
                f"doc-{i}",
                embedding.tolist(),
                {
                    "text": text,
                    "source": "pdf",
                    "chunk_id": i
                }
            )
        )
    return vectors
        

# index will be given by init_pinecone function  and insertion of vectors will be given by above function 

def batch_upsert(index, vectors, batch_size=100):
    for i in range(0, len(vectors), batch_size):
        index.upsert(vectors=vectors[i:i+batch_size])

# %% [markdown]
# ### Retrieval Pipeline

# %%
def join_context(matches):
    texts = []

    for match in matches:
        metadata = match.get("metadata", {})
        text = metadata.get("text", "")

        if text.strip():
            texts.append(text)

    return texts

# %%
def join_bm25_context(bm25_text):
    texts = bm25_text[0]   # get the inner list

    return [
        text for text in bm25_text[0]
        if text.strip()
    ]

# %%
from sentence_transformers import SentenceTransformer
from typing import List

model = SentenceTransformer("all-MiniLM-L6-v2")
# Out:
# Loading weights: 100%|██████████| 103/103 [00:00<00:00, 359.68it/s, Materializing param=pooler.dense.weight]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.

# %%
# docs=document_loader(r"docs\Recent_Wars_Final_Report_modified.pdf")
# final_chunk_docs=splitting_the_text(docs=docs)
# final_docs=formatting(final_chunk_docs=final_chunk_docs)




# embeddings,bm25_retriever=generate_embeddings(model=model,final_docs=final_docs)
# vectors=insertion_in_pinecone(final_docs=final_docs,embeddings=embeddings)

# # Insertion in vector db 
# batch_upsert(index, vectors=vectors, batch_size=100)

# %%
from sentence_transformers import CrossEncoder

reranker = CrossEncoder("BAAI/bge-reranker-base")
# Out:
# Loading weights: 100%|██████████| 201/201 [00:00<00:00, 447.61it/s, Materializing param=roberta.encoder.layer.11.output.dense.weight]
# XLMRobertaForSequenceClassification LOAD REPORT from: BAAI/bge-reranker-base
# Key                             | Status     |  |
# --------------------------------+------------+--+-
# roberta.embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.

# %%
def rank_documents(query: str, documents: List[str], reranker) -> List[str]:
    pairs = [
        (query, doc)
        for doc in documents
    ]
    scores = reranker.predict(pairs)

    ranked_docs = sorted(
        zip(scores, documents),
        key=lambda x: x[0],
        reverse=True
    )

    final_docs = [
        doc
        for score, doc in ranked_docs[:5]
    ]

    return final_docs

# %%
def find_context(
    query,
    index,
    model,
    bm25_retriever,
    final_docs,
    dense_k=10,
    bm25_k=10
):
    # -------------------------
    # 1. Dense retrieval
    # -------------------------
    query_vector = model.encode([query])[0]

    dense_results = index.query(
        vector=query_vector.tolist(),
        top_k=dense_k,
        include_metadata=True
    )

    dense_docs = []

    for match in dense_results["matches"]:
        text = match.get("metadata", {}).get("text", "")

        if text.strip():
            dense_docs.append(text)

    # -------------------------
    # 2. BM25 retrieval
    # -------------------------
    query_tokens = bm25s.tokenize(
        [query],
        stopwords="english"
    )

    bm25_results, bm25_scores = bm25_retriever.retrieve(
        query_tokens,
        corpus=final_docs,
        k=bm25_k
    )

    # bm25_results has shape:
    # [[doc1, doc2, ...]]

    bm25_docs = bm25_results[0].tolist()

    # -------------------------
    # 3. Combine
    # -------------------------
    combined_docs = dense_docs + bm25_docs

    # -------------------------
    # 4. Remove duplicates
    # -------------------------
    combined_docs = list(dict.fromkeys(combined_docs))

    return combined_docs

# %%
bm25_retriever = bm25s.BM25()
reranker = CrossEncoder("BAAI/bge-reranker-base")

def rag_pipeline(
    pdf_path: str,
    query: str,
    model,
    index,
    llm,
    batch_size: int = 100,
    bm25_retriever=None,
    reranker=None
):
    # 1. Load
    docs = document_loader(pdf_path)
    
    if bm25_retriever is None:
        bm25_retriever = bm25s.BM25()

    if reranker is None:
        reranker = CrossEncoder("BAAI/bge-reranker-base")

    # 2. Split
    final_chunk_docs = splitting_the_text(docs=docs)

    # 3. Format
    final_docs = formatting(final_chunk_docs=final_chunk_docs)

    # 4. Embeddings + BM25 index
    embeddings, bm25_retriever = generate_embeddings(
        model=model,
        final_docs=final_docs,
        bm25_retriever=bm25_retriever
    )

    # 5. Insert into Pinecone
    vectors = insertion_in_pinecone(
        final_docs=final_docs,
        embeddings=embeddings
    )

    batch_upsert(
        index,
        vectors=vectors,
        batch_size=batch_size
    )

    # 6. Hybrid retrieval
    combined_docs = find_context(
        query=query,
        index=index,
        model=model,
        bm25_retriever=bm25_retriever,
        final_docs=final_docs
    )

    # 7. Reranking
    context = rank_documents(
        query=query,
        documents=combined_docs,
        reranker=reranker
    )

    # 8. LLM
    chain = final_prompt | llm | StrOutputParser()

    response = chain.invoke({
        "context": context,
        "question": query
    })

    return response
# Out:
# Loading weights: 100%|██████████| 201/201 [00:00<00:00, 361.07it/s, Materializing param=roberta.encoder.layer.11.output.dense.weight]
# XLMRobertaForSequenceClassification LOAD REPORT from: BAAI/bge-reranker-base
# Key                             | Status     |  |
# --------------------------------+------------+--+-
# roberta.embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.

# %%
from pinecone import Pinecone

pc = Pinecone(api_key=os.getenv("PINECONE_API_KEY"))

load_dotenv()

index_name=os.getenv("INDEX_NAME")
index = pc.Index(
    name="vectordb",
    pool_threads=50,            
    connection_pool_maxsize=50, 
)
bm25_retriever = bm25s.BM25()

answer = rag_pipeline(
    pdf_path=r"docs\Recent_Wars_Final_Report_modified.pdf",
    query="What are the global impacts of war particularly in Ukraine?",
    model=model,
    index=index,
    llm=llm,
    bm25_retriever=bm25_retriever,
)
# Out:
# Loading weights: 100%|██████████| 201/201 [00:00<00:00, 459.66it/s, Materializing param=roberta.encoder.layer.11.output.dense.weight]
# XLMRobertaForSequenceClassification LOAD REPORT from: BAAI/bge-reranker-base
# Key                             | Status     |  |
# --------------------------------+------------+--+-
# roberta.embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.

# %%
print(answer)
# Out:
# The war in Ukraine has had several worldwide effects. International sanctions imposed on Russia have disrupted global energy markets, and the logistical challenges facing Ukrainian grain exports have threatened food security in regions that depend on those shipments. The conflict has also generated massive displacement, with more than 12 million people uprooted—over 7 million internally displaced within Ukraine and about 4.5 million refugees abroad. In response, the United States, European Union and other allies have provided military aid to Ukraine and engaged in diplomatic negotiations such as the Minsk agreements and 2024 cease‑fire talks.

# %%
answer = rag_pipeline(
    pdf_path=r"C:\Users\user\Desktop\RAG\docs\Recent_Wars_Final_Report_modified.pdf",
    query="",
    model=model,
    index=index,
    llm=llm
)
# Out:
# Loading weights: 100%|██████████| 201/201 [00:00<00:00, 283.32it/s, Materializing param=roberta.encoder.layer.11.output.dense.weight]
# XLMRobertaForSequenceClassification LOAD REPORT from: BAAI/bge-reranker-base
# Key                             | Status     |  |
# --------------------------------+------------+--+-
# roberta.embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.

# %%
answer
# Out:
# "I don't know the answer."

# %%
rag_evaluation_set = {
    "Q1": {
        "question": "What common structural drivers link the conflicts in Ukraine, Syria, Yemen, Ethiopia, Sudan, and Myanmar, and how do these drivers manifest differently across regions?",
        "answer": (
            "The conflicts share common structural drivers including state fragmentation, external patronage, "
            "and competition over resources. In Ukraine, this manifests through external military aid and sanctions "
            "shaping the battlefield. In Syria and Yemen, external patronage sustains proxy warfare. Ethiopia and "
            "Sudan reflect fragmentation through ethnic and military factionalism, while Myanmar combines political "
            "fragmentation after a coup with long-standing ethnic autonomy struggles."
        )
    },

    "Q2": {
        "question": "Which conflicts experienced significant escalation after 2020, and what triggering events caused this escalation?",
        "answer": (
            "Ukraine escalated in February 2022 following Russia’s full-scale invasion. Ethiopia’s Tigray conflict "
            "reignited in November 2020 due to tensions between the federal government and the TPLF. Myanmar’s "
            "civil war escalated after the February 1, 2021 military coup. Sudan’s conflict intensified after the "
            "April 2023 power struggle between the RSF and SAF. The DRC saw renewed violence between 2020 and 2024 "
            "due to the resurgence of M23 and expansion of the ADF."
        )
    },

    "Q3": {
        "question": "Which advanced military systems are explicitly mentioned in the Ukraine and Syria conflicts, and how do they differ in operational purpose?",
        "answer": (
            "In Ukraine, Russia employs long-range precision artillery such as the 9M729, while Ukraine relies on "
            "mobile drone fleets and Western-supplied air defense systems like Patriot and SAMP/T. In Syria, "
            "Russian S-300 air defense batteries integrated with Iranian-backed forces provide layered deterrence. "
            "Ukraine’s systems emphasize mobility and defense, while Syria’s focus on airspace denial."
        )
    },

    "Q4": {
        "question": "What numerical estimates are provided for displacement and economic loss across the conflicts?",
        "answer": (
            "Global displacement exceeds 30 million people. In the DRC, over 5 million people are internally "
            "displaced, mining export revenues declined by about 15% between 2020 and 2023, and armed groups divert "
            "around US$200 million annually. In Myanmar, GDP contracted by roughly 6% in 2023, about 7 million "
            "people face food insecurity, and over 1.2 million are internally displaced."
        )
    },

    "Q5": {
        "question": "How do armed conflicts disrupt resource-based economies in Ukraine, the DRC, and Myanmar?",
        "answer": (
            "In Ukraine, the war disrupted grain exports, contributing to higher global food prices. In the DRC, "
            "armed groups compete for control over coltan, tin, and gold, diverting revenues through illicit "
            "taxation. In Myanmar, jade and gemstone industries are increasingly controlled by armed groups, "
            "fueling a shadow economy and reducing state revenue."
        )
    },

    "Q6": {
        "question": "Compare the effectiveness and limitations of international mediation or intervention efforts in Yemen and the DRC.",
        "answer": (
            "In Yemen, the UN-mediated Stockholm Agreement remains largely unenforced with repeated ceasefire "
            "violations. In the DRC, MONUSCO conducts joint operations with the FARDC but is constrained by limited "
            "mandates, poor coordination, and criticism over civilian protection. Both cases show diplomatic "
            "fatigue and weak enforcement."
        )
    },

    "Q7": {
        "question": "How do asymmetric tactics interact with conventional military strategies in at least three conflicts discussed?",
        "answer": (
            "In Ukraine, Russian conventional combined-arms operations contrast with Ukraine’s asymmetric drone "
            "warfare. In Ethiopia, conventional heavy armor is combined with militia-based infantry tactics. In "
            "Myanmar, the Tatmadaw uses conventional artillery and airpower, while PDFs and EAOs rely on guerrilla "
            "tactics, ambushes, and IEDs, creating hybrid warfare environments."
        )
    },

    "Q8": {
        "question": "Identify two distinct social consequences unique to the DRC and Myanmar conflicts respectively.",
        "answer": (
            "In the DRC, severe gender-based violence, child soldier recruitment, and disease outbreaks in "
            "displacement camps are prominent. In Myanmar, education disruption for millions of children, forced "
            "labor, and rising refugee flows to Thailand and India are emphasized."
        )
    },

    "Q9": {
        "question": "Explain how sanctions indirectly affect battlefield dynamics in at least two conflicts.",
        "answer": (
            "Sanctions on Russia reshaped markets and constrained logistics, affecting battlefield sustainability. "
            "In Myanmar, sanctions targeting military leaders and revenue streams worsened logistical constraints, "
            "contributed to defections, lowered morale, and reduced the Tatmadaw’s operational effectiveness."
        )
    },

    "Q10": {
        "question": "Does the text indicate that MONUSCO conducts offensive operations without restrictions?",
        "answer": (
            "No. The text explicitly states that MONUSCO’s operations are constrained by mandates that limit "
            "offensive actions, which has reduced its effectiveness in protecting civilians."
        )
    }
}

# %%
docs = document_loader(
    r"docs\Recent_Wars_Final_Report_modified.pdf"
)

final_chunk_docs = splitting_the_text(docs=docs)

final_docs = formatting(
    final_chunk_docs=final_chunk_docs
)

bm25_retriever = bm25s.BM25()

embeddings, bm25_retriever = generate_embeddings(
    model=model,
    final_docs=final_docs,
    bm25_retriever=bm25_retriever
)

vectors = insertion_in_pinecone(
    final_docs=final_docs,
    embeddings=embeddings
)

batch_upsert(
    index,
    vectors=vectors,
    batch_size=100
)

reranker = CrossEncoder(
    "BAAI/bge-reranker-base"
)
# Out:
# Loading weights: 100%|██████████| 201/201 [00:00<00:00, 322.71it/s, Materializing param=roberta.encoder.layer.11.output.dense.weight]
# XLMRobertaForSequenceClassification LOAD REPORT from: BAAI/bge-reranker-base
# Key                             | Status     |  |
# --------------------------------+------------+--+-
# roberta.embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.

# %%
def rag_query(
    query,
    index,
    model,
    bm25_retriever,
    final_docs,
    llm,
    reranker
):

    # Hybrid retrieval
    combined_docs = find_context(
        query=query,
        index=index,
        model=model,
        bm25_retriever=bm25_retriever,
        final_docs=final_docs,
        dense_k=10,
        bm25_k=10
    )

    # Reranking
    context = rank_documents(
        query=query,
        documents=combined_docs,
        reranker=reranker
    )

    # Generation
    chain = final_prompt | llm | StrOutputParser()

    response = chain.invoke({
        "context": context,
        "question": query
    })

    return response

# %%
answers = {}

for q_id, qa in rag_evaluation_set.items():

    question_text = qa["question"]
    gold_answer = qa["answer"]

    rag_answer = rag_query(
        query=question_text,
        index=index,
        model=model,
        bm25_retriever=bm25_retriever,
        final_docs=final_docs,
        llm=llm,
        reranker=reranker
    )

    answers[q_id] = {
        "question": question_text,
        "original_answer": gold_answer,
        "rag_answer": rag_answer
    }

# %%
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np


def evaluate_rag_similarity(answers, model):
    results = {}

    for q_id, data in answers.items():

        original_answer = data["original_answer"]
        rag_answer = data["rag_answer"]

        # Create embeddings
        original_embedding = model.encode(
            [original_answer],
            normalize_embeddings=True
        )

        rag_embedding = model.encode(
            [rag_answer],
            normalize_embeddings=True
        )

        # Cosine similarity
        similarity = cosine_similarity(
            original_embedding,
            rag_embedding
        )[0][0]

        results[q_id] = {
            "question": data["question"],
            "original_answer": original_answer,
            "rag_answer": rag_answer,
            "cosine_similarity": float(similarity)
        }

    return results

# %%
similarity_results = evaluate_rag_similarity(
    answers=answers,
    model=model
)

# %%
average_similarity = np.mean([
    result["cosine_similarity"]
    for result in similarity_results.values()
])

print(f"Average Cosine Similarity: {average_similarity:.4f}")
# Out:
# Average Cosine Similarity: 0.3748

# %%
import pandas as pd

evaluation_df = pd.DataFrame([
    {
        "question_id": q_id,
        "question": result["question"],
        "original_answer": result["original_answer"],
        "rag_answer": result["rag_answer"],
        "cosine_similarity": result["cosine_similarity"]
    }
    for q_id, result in similarity_results.items()
])

evaluation_df
# Out:
#   question_id                                           question  \
# 0          Q1  What common structural drivers link the confli...
# 1          Q2  Which conflicts experienced significant escala...
# 2          Q3  Which advanced military systems are explicitly...
# 3          Q4  What numerical estimates are provided for disp...
# 4          Q5  How do armed conflicts disrupt resource-based ...
# 5          Q6  Compare the effectiveness and limitations of i...
# 6          Q7  How do asymmetric tactics interact with conven...
# 7          Q8  Identify two distinct social consequences uniq...
# 8          Q9  Explain how sanctions indirectly affect battle...
# 9         Q10  Does the text indicate that MONUSCO conducts o...
#
#                                      original_answer  \
# 0  The conflicts share common structural drivers ...
# 1  Ukraine escalated in February 2022 following R...
# 2  In Ukraine, Russia employs long-range precisio...
# 3  Global displacement exceeds 30 million people....
# 4  In Ukraine, the war disrupted grain exports, c...
# 5  In Yemen, the UN-mediated Stockholm Agreement ...
# 6  In Ukraine, Russian conventional combined-arms...
# 7  In the DRC, severe gender-based violence, chil...
# 8  Sanctions on Russia reshaped markets and const...
# 9  No. The text explicitly states that MONUSCO’s ...
#
#                                           rag_answer  cosine_similarity
# 0                           I don't know the answer.           0.068913
# 1  - **Tigray War (Ethiopia, 2020‑2022)** – Escal...           0.716709
# 2                           I don't know the answer.           0.026346
# 3  - Displacement estimates mentioned in the exce...           0.668568
# 4                           I don't know the answer.           0.079401
# 5  Both conflicts have seen international actors ...           0.700343
# 6  In Somalia, conventional Ethiopian National De...           0.726635
# 7                           I don't know the answer.           0.031062
# 8  Sanctions on Russia have been paired with larg...           0.626684
# 9                           I don't know the answer.           0.103074
